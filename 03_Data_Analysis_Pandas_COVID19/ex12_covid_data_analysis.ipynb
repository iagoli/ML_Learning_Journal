# %%
# Exercise: ex12_covid_data_analysis

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/11-08-2020.csv"
df = pd.read_csv(url)

# %%
# a) & b) Inspection
print("--- Dataset Info ---")
print(df.info())
print("\n--- First 5 Rows ---")
display(df.head())
print("\n--- Last 5 Rows ---")
display(df.tail())
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3997 entries, 0 to 3996
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3265 non-null   float64
#  1   Admin2               3270 non-null   object
#  2   Province_State       3819 non-null   object
#  3   Country_Region       3997 non-null   object
#  4   Last_Update          3997 non-null   object
#  5   Lat                  3911 non-null   float64
#  6   Long_                3911 non-null   float64
#  7   Confirmed            3997 non-null   int64
#  8   Deaths               3997 non-null   int64
#  9   Recovered            3997 non-null   int64
#  10  Active               3997 non-null   int64
#  11  Combined_Key         3997 non-null   object
#  12  Incidence_Rate       3911 non-null   float64
#  13  Case-Fatality_Ratio  3946 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# ...

# %%
# c) Aggregation by Country & Sort
cols = ['Confirmed', 'Recovered', 'Active', 'Deaths']
df_country = df.groupby('Country_Region')[cols].sum().sort_values('Confirmed', ascending=False)
display(df_sorted.head())
# Out:
#                 Confirmed  Recovered   Active  Deaths
# Country_Region
# US               10101963    3881491  9886814  238329
# India             8553657    7917373   509673  126611
# Brazil            5666389    5147172   354546  162538
# France            1837134     134095  1662549   40490
# Russia            1760420    1315928   414200   30292

# %%
# d) Portugal Ranking & Stats
rank_pt = df_country.index.get_loc('Portugal') + 1
print(f"\nPortugal Rank (Confirmed Cases): {rank_pt}")
print("\n--- Portugal Stats ---")
print(df_country.loc['Portugal'])
print("\n--- Global Stats Description ---")
print(df_country.describe())
# Out:
# Portugal Rank (Confirmed Cases): 35
#
# --- Portugal Stats ---
# Confirmed    179324
# Recovered     99781
# Active        76647
# Deaths         2896
# Name: Portugal, dtype: int64
#
# --- Global Stats Description ---
#           Confirmed     Recovered        Active         Deaths
# count  1.990000e+02  1.990000e+02  1.990000e+02     199.000000
# mean   2.541061e+05  1.661235e+05  1.053217e+05    6677.597990
# std    1.041095e+06  7.351185e+05  7.222073e+05   24969.634435
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    2.465000e+03  1.424000e+03  1.135000e+02      42.000000
# 50%    1.722300e+04  1.083800e+04  2.491000e+03     286.000000
# 75%    1.092610e+05  6.854500e+04  1.967100e+04    1825.000000
# max    1.010196e+07  7.917373e+06  9.886814e+06  238329.000000

# %%
# e) Top 10 Deaths
print("\n--- Top 10 Countries by Deaths ---")
print(df_country.sort_values('Deaths', ascending=False)['Deaths'].head(10))
# Out:
# --- Top 10 Countries by Deaths ---
# Country_Region
# US                238329
# Brazil            162538
# India             126611
# Mexico             95027
# Peru               87327
# United Kingdom     67377
# Italy              41394
# France             40490
# Spain              38833
# Iran               38291
# Name: Deaths, dtype: int64

# %%
# f) Fatality Rates
pt_fatality = (df_country.loc['Portugal', 'Deaths'] / df_country.loc['Portugal', 'Confirmed']) * 100
global_fatality = (df_country['Deaths'].sum() / df_country['Confirmed'].sum()) * 100

print(f"\nPortugal Fatality Rate: {pt_fatality:.2f}%")
print(f"Global Fatality Rate: {global_fatality:.2f}%")
# Out:
# Portugal Fatality Rate: 1.61%
# Global Fatality Rate: 2.63%
